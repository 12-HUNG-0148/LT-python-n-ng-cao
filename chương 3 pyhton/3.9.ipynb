# %%
# tạo data frame euro12 từ file csv euro 2012 
import numpy as np
import pandas as pd
euro12 = pd.read_csv('Euro_2012_stats_TEAM.csv')
print(euro12)

# ý 1
euro12["Goals"]

# ý 2
print(euro12["Team"].count(), "là tổng số đội tham gia euro 2012")

# ý 3
print(euro12, "là thông tin euro 2012")

# ý 4
discipline = euro12[["Team","Red Cards","Yellow Cards"]]
discipline

# ý 5
euro12.sort_values(by = ["Red Cards","Yellow Cards"])

# ý 6
tb_yellow = euro12["Yellow Cards"]
print(np.mean(tb_yellow), "là trung bình thẻ vàng nhận được")

# ý 7
euro12["Team"].fillna("o",inplace=True)
euro12[euro12.Team.str.startswith("G")]

# ý 8
print(euro12.columns[:7], "là thông tin 7 cột đầu euro12")

# ý 9
print(euro12.columns[:-3], "là thông tin các cột trừ 3 cột cuối")

# ý 10
euro12[["Team","Goals","Shooting Accuracy","Yellow Cards","Red Cards"]]

# ý 11
data = pd.read_csv("Euro_2012_stats_TEAM.csv",index_col= "Team")
data.loc[["England","Italy","Russia"]]["Shooting Accuracy"]
# Out:
#                                                  Team  Goals  Shots on target  \
# 0                                             Croatia    4.0             13.0
# 1                                      Czech Republic    4.0             13.0
# 2                                             Denmark    4.0             10.0
# 3                                             England    5.0             11.0
# 4                                              France    3.0             22.0
# 5                                             Germany   10.0             32.0
# 6                                              Greece    5.0              8.0
# 7                                               Italy    6.0             34.0
# 8                                         Netherlands    2.0             12.0
# 9                                              Poland    2.0             15.0
# 10                                           Portugal    6.0             22.0
# ...
